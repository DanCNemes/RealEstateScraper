# %%
import pandas as pd
import numpy
import os
from database import DbCluj
from bokeh.models import ColumnDataSource
from bokeh.palettes import Spectral10
from bokeh.plotting import figure
from bokeh.sampledata.autompg import autompg as df
from bokeh.transform import factor_cmap
from bokeh.embed import components
from bokeh.resources import CDN

os.listdir('.')
# Out:
# ['.git',
#  '.gitignore',
#  '.idea',
#  '.ipynb_checkpoints',
#  'cluj_real_estate_jupyter.ipynb',
#  'config.py',
#  'database.py',
#  'ghostdriver.log',
#  'groupby123.html',
#  'README.md',
#  'RealEstateScraper.py',
#  'venv',
#  '__pycache__']

# %%
cluj_db = DbCluj()
df = pd.read_sql_table('real_estate_cluj', cluj_db.engine)
# Out:
#         id              location  rooms_num  dimension      level  \
# 0       62   Cluj-Napoca,Mărăşti          3      60.00   Etaj 2/4
# 1       63  Cluj-Napoca,Mănăştur          2      61.00  Etaj 3/11
# 2       64   Cluj-Napoca,Central          3      77.14  Etaj 4/21
# 3       65   Cluj-Napoca,Central          2      57.11  Etaj 3/21
# 4       66   Cluj-Napoca,Zorilor          3      75.00  Etaj 1/10
# ...    ...                   ...        ...        ...        ...
# 8203  8261   Cluj-Napoca,Central          2      45.33   Parter/4
# 8204  8263  Cluj-Napoca,Mănăştur          4      61.00   Etaj 2/4
# 8205  8265   Cluj-Napoca,Mărăşti          1      46.00  Etaj 1/10
# 8206  8267  Cluj-Napoca,Borhanci          3      83.77   Etaj 1/3
# 8207  8269  Cluj-Napoca,Mănăştur          3      64.00   Parter/4
#
#         architecture    price   currency scraped_date
# 0         Decomandat  113.900        EUR   2020-06-08
# 1         Decomandat   81.900        EUR   2020-06-08
# ...

# %%
import pandas as pd
from database import DbCluj
from bokeh.models import ColumnDataSource
from bokeh.palettes import Spectral10
from bokeh.plotting import figure, show, output_file
from bokeh.sampledata.autompg import autompg as df
from bokeh.transform import factor_cmap
from bokeh.embed import components
from bokeh.resources import CDN

output_file('plot.html')

cluj_db = DbCluj()
df = pd.read_sql_table('real_estate_cluj', cluj_db.engine)
df.rooms_num = df.rooms_num.astype(str)
group = df.groupby('rooms_num')

source = ColumnDataSource(group)

rooms_cmap = factor_cmap('rooms_num', palette=Spectral10, factors=sorted(df.rooms_num.unique()))

p = figure(plot_height=350, plot_width=1500, x_range=group, title="Mean price (EUR, 1000's)",
           toolbar_location=None, tools="")

p.vbar(x='rooms_num', top='price_mean', width=1, source=source,
       line_color=rooms_cmap, fill_color=rooms_cmap)

p.y_range.start = 0
p.xgrid.grid_line_color = None
p.xaxis.axis_label = "Number of rooms"
p.xaxis.major_label_orientation = 1.2
p.outline_line_color = None

rooms_script, rooms_div = components(p)
cdn_js = CDN.js_files
cdn_css = CDN.css_files
cdn_css

show(p)

# %%
output_file('plot.html')

cluj_db = DbCluj()
df = pd.read_sql_table('real_estate_cluj', cluj_db.engine)
df.rooms_num = df.rooms_num.astype(str)
group = df.groupby('location')

source = ColumnDataSource(group)

rooms_cmap = factor_cmap('location', palette=Spectral10, factors=sorted(df.rooms_num.unique()))

p = figure(plot_height=350, plot_width=1500, x_range=group, title="Mean price (EUR, 1000's)",
           toolbar_location=None, tools="")

p.vbar(x='location', top='price_mean', width=1, source=source,
       line_color=rooms_cmap, fill_color=rooms_cmap)

p.y_range.start = 0
p.xgrid.grid_line_color = None
p.xaxis.axis_label = "location in Cluj-Napoca"
p.xaxis.major_label_orientation = 1.2
p.outline_line_color = None

rooms_script, rooms_div = components(p)
cdn_js = CDN.js_files
cdn_css = CDN.css_files
cdn_css

show(p)
